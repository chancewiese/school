# %%
# 1
# Chance Wiese

# %%
# 2
import os
import pandas as pd

path = '/Users/chancewiese/Dropbox/5330corgis'
files = os.listdir(path)

for file in files:
    print(file)
# Out:
# 102121-7380.csv
# pdx623.csv
# 102121-5390.csv
# portlandeventjun22.csv
# newreg-062822.csv
# 102123-3428.csv
# 102124-9377.csv
# Icon
# newcorgis-20220619.csv
# newcorgis-20220618.csv
# signupsjune272022.csv
# 102124-3988.csv
# 102119-8469.csv
# tacoma-062322.csv
# 102122-4015.csv
# 102120-8243.csv

# %%
# 3
import psycopg2

conn = psycopg2.connect(
    database='corgirace',
    user='dw_chancewiese',
    password='Spikeball2020',
    host='database-1.czsooswggscz.us-east-2.rds.amazonaws.com',
    port='5432'
)

cursor = conn.cursor()

query = "SELECT * FROM ingest;"
df_ingest = pd.read_sql_query(query, conn)

for file in files:
    file_path = os.path.join(path, file)
    file_lower = file.lower()
    
    if not file.endswith('.csv'):
        continue
    
    if file_lower in df_ingest['filename'].values:
        print(f"{file_lower} has already been processed.")
        continue
        
    with open(file_path, 'r') as newfile:
        next(newfile)
        print(f"Processing {file_lower}:")
        for line in newfile:
            issueslist = []
            
            line = line.strip()
            columns = line.split(',')
            
            if len(columns) > 5:
                issueslist.append("Too Many Columns")
            elif len(columns) < 5:
                issueslist.append("Too Few Columns")
            
            name = columns[0]
            if len(name) < 1:
                issueslist.append("Name Too Short")
            elif len(name) > 100:
                issueslist.append("Name Too Long")
            
            breed = columns[1]
            if not breed.upper().startswith(('P', 'C')):
                issueslist.append("Breed Issue")
                
            gender = columns[2]
            if gender.upper() not in ['M', 'F', 'SF', 'NM']:
                issueslist.append("Gender Col Issue")
                
            try:
                weight = float(columns[3])
                if weight < 15:
                    issueslist.append("Weight Too Low")
                elif weight > 35:
                    issueslist.append("Weight Too High")
            except ValueError:
                issueslist.append("Weight Non-Numeric")
                
            try:
                age = float(columns[4])
                if age < 1:
                    issueslist.append("Age Too Low")
                elif age > 10:
                    issueslist.append("Age Too High")
            except ValueError:
                issueslist.append("Age Non-Numeric")
                
            print(f"file: {file_lower}, name: {name if len(name) > 0 else 'no_name'}, issues: {issueslist}")
# Out:
# Processing 102121-7380.csv:
# file: 102121-7380.csv, name: Speedbump, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: Bandit, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: Bailey Barkbark, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: Trucky McDog, issues: ['Too Many Columns', 'Age Too Low']
# file: 102121-7380.csv, name: Oakley Ann, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: Maverick, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: Rancher, issues: ['Too Many Columns', 'Weight Too High', 'Age Too High']
# file: 102121-7380.csv, name: Bowser, issues: ['Too Many Columns']
# file: 102121-7380.csv, name: no_name, issues: ['Too Many Columns', 'Name Too Short']
# file: 102121-7380.csv, name: no_name, issues: ['Too Many Columns', 'Name Too Short']
# pdx623.csv has already been processed.
# Processing 102121-5390.csv:
# file: 102121-5390.csv, name: Governess Moonbeam, issues: []
# file: 102121-5390.csv, name: Drumstick, issues: []
# file: 102121-5390.csv, name: Punchy Judy, issues: []
# file: 102121-5390.csv, name: Hywel the Woofer, issues: []
# file: 102121-5390.csv, name: Jerry Brown, issues: ['Gender Col Issue']
# portlandeventjun22.csv has already been processed.
# newreg-062822.csv has already been processed.
# Processing 102123-3428.csv:
# file: 102123-3428.csv, name: Brunchkiller, issues: []
# file: 102123-3428.csv, name: Igloo, issues: []
# file: 102123-3428.csv, name: Goblin, issues: []
# file: 102123-3428.csv, name: Campstove, issues: []
# file: 102123-3428.csv, name: Baby Congrats, issues: ['Weight Too High']
# file: 102123-3428.csv, name: no_name, issues: ['Name Too Short']
# Processing 102124-9377.csv:
# file: 102124-9377.csv, name: Piper the Pip, issues: ['Too Many Columns', 'Age Non-Numeric']
# file: 102124-9377.csv, name: Road Hazard, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Tigerstripe, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Woofsnarl Jim, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: PacDog, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Smöke Screen, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Goose, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Samwise, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Super Nova, issues: ['Too Many Columns', 'Breed Issue']
# file: 102124-9377.csv, name: Penny the Shiny, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Double-Dragon, issues: ['Too Many Columns']
# file: 102124-9377.csv, name: Grumbledog, issues: ['Too Many Columns']
# newcorgis-20220619.csv has already been processed.
# newcorgis-20220618.csv has already been processed.
# signupsjune272022.csv has already been processed.
# Processing 102124-3988.csv:
# file: 102124-3988.csv, name: Delbert the Cog, issues: []
# file: 102124-3988.csv, name: Leonidis, issues: []
# file: 102124-3988.csv, name: Rattler, issues: []
# file: 102124-3988.csv, name: Crossbow Jo, issues: ['Gender Col Issue', 'Weight Too Low']
# file: 102124-3988.csv, name: Her Eminence Lady Snoot, issues: []
# file: 102124-3988.csv, name: Rancher, issues: []
# file: 102124-3988.csv, name: Pinky and the Brain humorously explores ambition friendship and failure as a genius mouses schemes for world domination are foiled by his goofy companion, issues: ['Name Too Long']
# Processing 102119-8469.csv:
# file: 102119-8469.csv, name: Neck-Nipping Nellie, issues: ['Gender Col Issue', 'Age Too High']
# file: 102119-8469.csv, name: Finnleberry Huck, issues: []
# file: 102119-8469.csv, name: Wyvern, issues: []
# file: 102119-8469.csv, name: Ogre, issues: []
# file: 102119-8469.csv, name: Zap, issues: []
# file: 102119-8469.csv, name: no_name, issues: ['Name Too Short']
# tacoma-062322.csv has already been processed.
# Processing 102122-4015.csv:
# file: 102122-4015.csv, name: Hildegard von Doggen, issues: []
# file: 102122-4015.csv, name: Baby Bear, issues: []
# file: 102122-4015.csv, name: Corgihor, issues: []
# file: 102122-4015.csv, name: Max-Min, issues: []
# file: 102122-4015.csv, name: Demi Locorgo, issues: []
# file: 102122-4015.csv, name: Double-Plus, issues: ['Weight Non-Numeric']
# file: 102122-4015.csv, name: T-Rex Legs, issues: ['Weight Too Low']
# Processing 102120-8243.csv:
# file: 102120-8243.csv, name: Megawoof, issues: ['Weight Too High', 'Age Too High']
# file: 102120-8243.csv, name: Charles, issues: ['Gender Col Issue', 'Weight Too High']
# file: 102120-8243.csv, name: Mabel the Claw, issues: []
# file: 102120-8243.csv, name: Instant Breakfast, issues: []
# file: 102120-8243.csv, name: Willow The Dust Storm Corgifriend, issues: []
# file: 102120-8243.csv, name: Empanada, issues: []
# file: 102120-8243.csv, name: Leatherface, issues: []
# file: 102120-8243.csv, name: Corgi Elliot, issues: []
# file: 102120-8243.csv, name: Tobias, issues: []
# file: 102120-8243.csv, name: Nature Girl Nala, issues: ['Gender Col Issue', 'Weight Non-Numeric']
# file: 102120-8243.csv, name: Mountain Man, issues: []
# file: 102120-8243.csv, name: Loofah, issues: []
# file: 102120-8243.csv, name: Amelia the Woof, issues: ['Breed Issue', 'Gender Col Issue']
# /var/folders/96/kzlzzx2556jf68c57bc_gc180000gn/T/ipykernel_17427/2818981052.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_ingest = pd.read_sql_query(query, conn)

# %%
# 4
cursor.execute('''
CREATE TABLE IF NOT EXISTS corgi_exception (
    exceptid SERIAL PRIMARY KEY,
    except_record TEXT,
    origin_file VARCHAR(100) NOT NULL,
    issues TEXT,
    except_timestamp TIMESTAMP,
    fixed_timestamp TIMESTAMP
);
''')

conn.commit()

# %%
# 5
for file in files:
    file_path = os.path.join(path, file)
    file_lower = file.lower()
    
    if not file.endswith('.csv'):
        continue
       
    if file_lower in df_ingest['filename'].values:
        print(f"{file_lower} has already been processed.")
        continue
    
    with open(file_path, 'r') as newfile:
        next(newfile)
        
        for line in newfile:
            issueslist = []
            
            line = line.strip()
            columns = line.split(',')
            
            compliant = True
            
            if len(columns) != 5:
                compliant = False
                issueslist.append("Column Issue")
            else:
                name = columns[0].replace("'", "")
                if len(name) < 1 or len(name) > 100:
                    compliant = False
                    issueslist.append("Name Issue")
                
                breed = columns[1].lower()
                if breed.startswith('p'):
                    breed = 'Pem'
                elif breed.startswith('c'):
                    breed = 'Cardi'
                else:
                    compliant = False
                    issueslist.append("Breed Issue")
                
                gender = columns[2].upper()
                if gender not in ['M', 'F', 'NM', 'SF']:
                    compliant = False
                    issueslist.append("Gender Issue")
                
                try:
                    weight = float(columns[3])
                    if weight < 15 or weight > 35:
                        compliant = False
                        issueslist.append("Weight Issue")
                    else:
                        weight = round(weight)
                except ValueError:
                    compliant = False
                    issueslist.append("Weight Non-Numeric")
                
                try:
                    age = float(columns[4])
                    if age < 1 or age > 10:
                        compliant = False
                        issueslist.append("Age Issue")
                    else:
                        age = round(age * 2) / 2
                except ValueError:
                    compliant = False
                    issueslist.append("Age Non-Numeric")
            
            if compliant:
                cursor.execute(f'''
                    INSERT INTO corgi (corgname, breed, gender, weight, age, fromfile)
                    VALUES ('{name}', '{breed}', '{gender}', {weight}, {age}, '{file_lower}');
                ''')
                conn.commit()
                print(f"Record created for {name}")
            else:
                record_string = '|'.join(columns)
                issues_string = '|'.join(issueslist)
                
                cursor.execute(f'''
                    INSERT INTO corgi_exception 
                    (except_record, origin_file, issues, except_timestamp)
                    VALUES ('{record_string}', '{file_lower}', '{issues_string}', current_timestamp);
                ''')
                conn.commit()
                print(f"Record for {columns[0]} had these issues: {issueslist}")
    
    cursor.execute(f'''
        INSERT INTO ingest (filename, whendone)
        VALUES ('{file_lower}', current_timestamp);
    ''')
    conn.commit()
    print(f"Ingestion complete for {file_lower}.")

# %%
# 6
query = '''
SELECT exceptid, except_record, origin_file 
FROM corgi_exception 
ORDER BY except_record 
LIMIT 10;
'''

df_exceptions = pd.read_sql_query(query, conn, index_col='exceptid')
print("\ncorgi_exception table:\n", df_exceptions)

# %%
# 7
query = '''
SELECT corgid, corgname, weight, age, fromfile
FROM corgi
WHERE DATE(whendone) = CURRENT_DATE
ORDER BY corgname
LIMIT 10;
'''

df_corgi = pd.read_sql_query(query, conn, index_col='corgid')
print("\ncorgi table:\n", df_corgi)

# %%
cursor.close()
conn.close()
