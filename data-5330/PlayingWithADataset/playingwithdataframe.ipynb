# %%
import pandas as pd
df = pd.read_csv('overland-days.csv')
print(df)
# Out:
#        DateID        DOW    Price Holiday Skies  HiTemp  Wind  NewSnow  \
# 0    20161210   Saturday  Weekday       n  Snow      33    12        3
# 1    20161211     Sunday  Weekday       n  Snow      23     4        4
# 2    20161212     Monday  Weekday       n   Sun      22     8        0
# 3    20161213    Tuesday  Weekday       n  Snow      25    19        6
# 4    20161214  Wednesday  Weekday       n   Fog      13    17        0
# ..        ...        ...      ...     ...   ...     ...   ...      ...
# 115  20170404    Tuesday  Weekday       n   Sun      51     7        0
# 116  20170405  Wednesday  Weekday       n  Rain      46    12        0
# 117  20170406   Thursday  Weekday       n   Sun      35    14        0
# 118  20170407     Friday  Weekday       n   Sun      49    10        0
# 119  20170408   Saturday     Peak       n   Sun      54     5        0
#
#      BaseDepth  GuestCount     Month
# 0           16         291  December
# 1           29         541  December
# ...

# %%
print(df['GuestCount'].describe())
# Out:
# count     120.000000
# mean      523.416667
# std       326.675348
# min        19.000000
# 25%       281.750000
# 50%       500.000000
# 75%       692.500000
# max      1585.000000
# Name: GuestCount, dtype: float64

# %%
print(df[['Month', 'GuestCount']].groupby('Month').describe())
# Out:
#          GuestCount                                                       \
#               count        mean         std    min    25%    50%     75%
# Month
# April           8.0  217.250000  202.432881   62.0   80.5  169.5  224.00
# December       22.0  568.954545  381.797563   19.0  301.0  543.5  706.75
# February       28.0  513.500000  273.593440   51.0  341.0  481.0  694.50
# January        31.0  693.516129  342.411241  193.0  463.0  662.0  792.00
# March          31.0  408.967742  238.858324   28.0  251.5  390.0  579.50
#
#
#              max
# Month
# April      671.0
# December  1357.0
# February  1171.0
# January   1585.0
# March     1095.0

# %%
print(df[['Month', 'DOW', 'GuestCount']].groupby(['Month', 'DOW']).describe())
# Out:
#                    GuestCount                                                  \
#                         count         mean         std    min     25%     50%
# Month    DOW
# April    Friday           1.0    67.000000         NaN   67.0   67.00    67.0
#          Monday           1.0   183.000000         NaN  183.0  183.00   183.0
#          Saturday         2.0   239.500000  118.086832  156.0  197.75   239.5
#          Sunday           1.0   671.000000         NaN  671.0  671.00   671.0
#          Thursday         1.0    85.000000         NaN   85.0   85.00    85.0
#          Tuesday          1.0   191.000000         NaN  191.0  191.00   191.0
#          Wednesday        1.0    62.000000         NaN   62.0   62.00    62.0
# December Friday           3.0   715.333333  609.214522   22.0  490.50   959.0
#          Monday           3.0   368.666667  165.814153  183.0  302.00   421.0
#          Saturday         4.0   798.000000  397.044078  291.0  610.50   837.0
# ...

# %%
df2 = df[(df['Month'] == 'January') | (df['Month'] == 'February')]
print(df2)
# Out:
#       DateID        DOW    Price Holiday   Skies  HiTemp  Wind  NewSnow  \
# 22  20170101     Sunday     Peak       y     Sun      -4     8        0
# 23  20170102     Monday     Peak       y     Sun       3    10        0
# 24  20170103    Tuesday  Weekday       n     Sun      15    11        0
# 25  20170104  Wednesday  Weekday       n    Snow      19     7        2
# 26  20170105   Thursday  Weekday       n    Snow      25     7        1
# 27  20170106     Friday  Weekday       n     Fog      23     2        0
# 28  20170107   Saturday     Peak       n    Snow      15     5        1
# 29  20170108     Sunday     Peak       n  Cloudy      14     9        0
# 30  20170109     Monday  Weekday       n     Sun      17     9        0
# 31  20170110    Tuesday  Weekday       n     Sun      11     5        0
# 32  20170111  Wednesday  Weekday       n    Snow      13     4        2
# 33  20170112   Thursday  Weekday       n     Sun      18     9        0
# ...
